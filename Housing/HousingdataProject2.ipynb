# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import mpl_toolkits
# %matplotlib inline

# %%
import seaborn as sns

# %%
### Read the DataSet
data = pd.read_csv('HousingData.csv' , delimiter = ',')

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data['bedrooms'].value_counts().plot(kind = 'bar')
plt.title('Number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(data.price,data.area)
plt.title("Price Vs Area")
# Out:
# Text(0.5, 1.0, 'Price Vs Area')

# %%
plt.scatter(data.price,data.parking)
plt.title("Price Vs Parking")
# Out:
# Text(0.5, 1.0, 'Price Vs Parking')

# %%
raw_data = pd.read_csv('HousingData.csv')

# %%
sns.pairplot(raw_data)

# %%
Index=(['price','area','bedrooms','bathrooms','stories','parking'])

x = raw_data[['area','bedrooms','bathrooms','stories','parking']]
y = raw_data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
# Out:
# [3.21898375e+02 1.63519212e+05 1.10559065e+06 5.44852972e+05
#  3.54780582e+05]

# %%
print(model.intercept_)
# Out:
# -57540.09660239238

# %%
pd.DataFrame(model.coef_, x.columns, columns = ['Coeff'])
# Out:
#                   Coeff
# area       3.218984e+02
# bedrooms   1.635192e+05
# bathrooms  1.105591e+06
# stories    5.448530e+05
# parking    3.547806e+05

# %%
predictions = model.predict(x_test)

# %%
plt.scatter(y_test, predictions)

# %%
plt.hist(y_test - predictions)
# Out:
# (array([ 6., 21., 53., 49., 21.,  7.,  3.,  3.,  0.,  1.]),
#  array([-2485527.83769881, -1661007.46044995,  -836487.0832011 ,
#           -11966.70595224,   812553.67129662,  1637074.04854548,
#          2461594.42579433,  3286114.80304319,  4110635.18029205,
#          4935155.5575409 ,  5759675.93478976]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn import metrics

# %%
metrics.mean_absolute_error(y_test, predictions)
# Out:
# 859650.7336627761

# %%
metrics.mean_squared_error(y_test, predictions)
# Out:
# 1388089687120.566

# %%
np.sqrt(metrics.mean_squared_error(y_test, predictions))
# Out:
# 1178172.1805918547

# %%
##### logistic Regression

# %%
from sklearn.metrics import accuracy_score  
from sklearn.linear_model import LogisticRegression

# %%
#reading training File  
tr=open("HousingData.csv","r")  
records=tr.readlines()  
tr.close()

# %%
data['bedrooms'].unique()
# Out:
# array([4, 3, 5, 2, 6, 1], dtype=int64)

# %%
data['basement'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['price'].value_counts()
# Out:
# 4200000     17
# 3500000     17
# 4900000     12
# 5250000      9
# 3150000      9
#             ..
# 11410000     1
# 8680000      1
# 6419000      1
# 8080940      1
# 8960000      1
# Name: price, Length: 219, dtype: int64

# %%
sns.countplot(x='price',data=data,palette="hls")
plt.show()
plt.savefig('count_plot')

# %%
data['bedrooms'].value_counts()
# Out:
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: bedrooms, dtype: int64

# %%
sns.countplot(x='bedrooms',data=data,palette="hls")
plt.show()
plt.savefig('count_plot')

# %%
data.groupby('bedrooms').mean()
# Out:
#                  price         area  bathrooms   stories   parking
# bedrooms
# 1         2.712500e+06  3710.000000   1.000000  1.000000  0.000000
# 2         3.632022e+06  4636.235294   1.058824  1.169118  0.492647
# 3         4.954598e+06  5226.620000   1.266667  1.933333  0.723333
# 4         5.729758e+06  5582.063158   1.621053  2.305263  0.915789
# 5         5.819800e+06  6291.500000   1.800000  2.000000  0.600000
# 6         4.791500e+06  3950.000000   1.500000  2.000000  0.500000

# %%
#%matplotlib inline
pd.crosstab(data.bedrooms,data.bathrooms).plot(kind='bar')
plt.title(' Bedrroms And Bathrooms')
plt.xlabel('bedrooms')
plt.ylabel('Bathrooms')
plt.savefig('Bedrooms and bathrooms')

# %%
pd.crosstab(data.parking,data.stories).plot(kind='bar')
plt.title('Parking and Stories')
plt.xlabel('parking')
plt.ylabel('stories')
plt.savefig('Parking Vs Stories')

# %%
import statsmodels.api as sm

# %%
x_train = sm.add_constant(x_train)

# %%
print(x_train)
# Out:
#      const   area  bedrooms  bathrooms  stories  parking
# 296    1.0   4600         3          2        2        1
# 236    1.0   2870         2          1        2        0
# 298    1.0   5800         3          1        1        2
# 412    1.0   2610         3          1        2        0
# 165    1.0   6450         3          2        1        0
# ..     ...    ...       ...        ...      ...      ...
# 64     1.0  11175         3          1        1        1
# 273    1.0   3500         4          1        2        2
# 449    1.0   1650         3          1        2        0
# 225    1.0   6440         2          1        1        3
# 77     1.0   6500         3          2        3        0
#
# [381 rows x 6 columns]

# %%
print(y_train)
# Out:
# 296    4200000
# 236    4620000
# 298    4200000
# 412    3430000
# 165    5383000
#         ...
# 64     7000000
# 273    4340000
# 449    3150000
# 225    4753000
# 77     6650000
# Name: price, Length: 381, dtype: int64

# %%
x_train = sm.add_constant(x_train)

# %%
model = sm.OLS(y_train, x_train)

# %%
results = model.fit()

# %%
 print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     85.91
# Date:                Wed, 12 May 2021   Prob (F-statistic):           5.30e-60
# Time:                        17:28:25   Log-Likelihood:                -5893.4
# No. Observations:                 381   AIC:                         1.180e+04
# Df Residuals:                     375   BIC:                         1.182e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.754e+04    3.1e+05     -0.186      0.853   -6.67e+05    5.52e+05
# ...

# %%
print('coefficient of determination:', results.rsquared)
# Out:
# coefficient of determination: 0.5339015658928323

# %%
print('adjusted coefficient of determination:', results.rsquared_adj)
# Out:
# adjusted coefficient of determination: 0.5276869201047367

# %%
print('regression coefficients:', results.params)
# Out:
# regression coefficients: const       -5.754010e+04
# area         3.218984e+02
# bedrooms     1.635192e+05
# bathrooms    1.105591e+06
# stories      5.448530e+05
# parking      3.547806e+05
# dtype: float64

# %%
print('predicted response:', results.fittedvalues, sep='\n')
# Out:
# predicted response:
# 296    5.569418e+06
# 236    3.388643e+06
# 298    4.660033e+06
# 412    3.468469e+06
# 165    5.265296e+06
#            ...
# 64     6.035456e+06
# 273    4.628039e+06
# 449    3.159446e+06
# 225    5.057309e+06
# 77     6.371097e+06
# Length: 381, dtype: float64

# %%
 print('predicted response:', results.predict(x_train), sep='\n')
# Out:
# predicted response:
# 296    5.569418e+06
# 236    3.388643e+06
# 298    4.660033e+06
# 412    3.468469e+06
# 165    5.265296e+06
#            ...
# 64     6.035456e+06
# 273    4.628039e+06
# 449    3.159446e+06
# 225    5.057309e+06
# 77     6.371097e+06
# Length: 381, dtype: float64
